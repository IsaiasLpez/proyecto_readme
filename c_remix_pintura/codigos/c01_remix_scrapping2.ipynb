# %%
## IMPORTAR LIBRERÍAS: 

import pandas as pd # para trabajar con datios
import matplotlib.pyplot as plt # importar libreria visualizacion.

import requests # para conectarse a las url de las noticias en la web
from bs4 import BeautifulSoup # para hacer scraping desde sitios web permote seleccinar los tags y capturar los elementos que contiene 

import unicodedata2

# %%
##Agustina Gutierrez
l_ulr1 = [ "https://pinturachilena.cl/obras/escena-domestica/"]
##Alberto Valenzuela Llanos
l_ulr2 = [ "https://pinturachilena.cl/obras/plaza-del-erbe-verona/", "https://pinturachilena.cl/obras/paisaje-costero/", 
          "https://pinturachilena.cl/obras/paisaje-71/", "https://pinturachilena.cl/obras/paisaje-marino/", 
          "https://pinturachilena.cl/obras/otono-en-lo-contador/", "https://pinturachilena.cl/obras/marina-de-valparaiso-2/", 
          "https://pinturachilena.cl/obras/lo-contador-al-atardecer/", "https://pinturachilena.cl/obras/a-figure-on-the-shore-una-figura-en-la-costa/", 
          "https://pinturachilena.cl/obras/calle-de-pueblo-4/", "https://pinturachilena.cl/obras/cardenales-de-algarrobo/", 
          "https://pinturachilena.cl/obras/toledo/", "https://pinturachilena.cl/obras/primavera-en-lo-contador/"]
##Alfredo Valenzuela Puelma
l_ulr3 = [ "https://pinturachilena.cl/obras/retrato-de-senora/", "https://pinturachilena.cl/obras/jarron-japones-con-flores/",
          "https://pinturachilena.cl/obras/camino-rural/", "https://pinturachilena.cl/obras/autorretrato-25/",
          "https://pinturachilena.cl/obras/jarron-con-flores-4/", "https://pinturachilena.cl/obras/en-un-parque-de-paris/", 
          "https://pinturachilena.cl/obras/mujer-del-abanico/", "https://pinturachilena.cl/obras/naturaleza-muerta-japonesa/",
          "https://pinturachilena.cl/obras/quebrada-de-la-cordillera-de-chillan/", "https://pinturachilena.cl/obras/el-turquito/",
          "https://pinturachilena.cl/obras/crisantemos/", "https://pinturachilena.cl/obras/almendro-florido/",
          "https://pinturachilena.cl/obras/mujer-del-sillon/", "https://pinturachilena.cl/obras/futuro-almirante/",
          "https://pinturachilena.cl/obras/ser-muy-querido/", "https://pinturachilena.cl/obras/meditacion/",
          "https://pinturachilena.cl/obras/bandolero/"]
##Arturo Gordon
l_ulr4 = [ "https://pinturachilena.cl/obras/retrato-de-dama-de-rojo/", "https://pinturachilena.cl/obras/paisaje-90/",
          "https://pinturachilena.cl/obras/marina-3/", "https://pinturachilena.cl/obras/escena-gitana/",
          "https://pinturachilena.cl/obras/mujer-y-nina/", "https://pinturachilena.cl/obras/estacion-pirque-santiago/", 
          "https://pinturachilena.cl/obras/la-captura-de-caupolican/", "https://pinturachilena.cl/obras/campesina-con-bandeja-con-frutas/",
          "https://pinturachilena.cl/obras/caleta-de-pescadores-3/", "https://pinturachilena.cl/obras/jugadores-de-cartas/",
          "https://pinturachilena.cl/obras/paisaje-7/", "https://pinturachilena.cl/obras/mercado/",
          "https://pinturachilena.cl/obras/laguna-del-llano-subercaseaux-2/", "https://pinturachilena.cl/obras/estatua-de-bernardo-ohiggins/",
          "https://pinturachilena.cl/obras/plaza-de-la-compania/", "https://pinturachilena.cl/obras/plaza-baquedano/",
          "https://pinturachilena.cl/obras/parque-4/", "https://pinturachilena.cl/obras/la-gitana-esmeralda-el-llano-subercaseaux/",
          "https://pinturachilena.cl/obras/fuente-de-diana-versailles/", "https://pinturachilena.cl/obras/paisaje-al-atardecer/",
          "https://pinturachilena.cl/obras/plaza-baquedano-santiago/", "https://pinturachilena.cl/obras/laguna-del-llano-subercaseaux/",
          "https://pinturachilena.cl/obras/fuente-de-diana-versailles2/"]
##Raquel González Acevedo
l_ulr19 = [ "https://pinturachilena.cl/obras/retrato-de-nina-6/"]




## Preguntar por respuesta desde el servidor que aloja la página. 
req = requests.get(l_ulr2[0],
                    headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' })
larespuesta = req.status_code 

## mostrar respuesta, se puede demorar un poco
print( larespuesta )
# Out:
# 200

# %%
## Ver HTML  
soup = BeautifulSoup(req.content.decode("utf-8"),  "html.parser")
# mostrar el html
#soup1

# Mostrar elemento a ver si toma
ejemplo = soup.find("h1").text.strip() 
# mostrar
print( ejemplo )
# Out:
# Plaza del Erbe, Verona

# %%
# Ejemplos estáticos 
# obtiene el elemento d_instit     = soup.find("div", class_="field--name-institution-id").text.strip() 
# selecciona el valor, no la variable d_instit = d_instit.split("\n")[1]

d_titulo = soup.find("h1", class_="case27-primary-text").text.strip() 
d_titulo = d_titulo.split("\n")[0]
##
d_creador = soup.find("span", class_="category-name").text.strip() 
d_creador = d_creador.split("\n")[0]
##
d_geoRef     = soup.find("div", class_="map-block-address").text.strip() 
d_geoRef  = d_geoRef.split("\n")[0]
##
d_tecnica = soup.find("ul", class_="extra-details").find_all("li")[0].find_all("div")[1]
d_tecnica = d_tecnica.get_text(strip=True)
##
d_fecha = soup.find("ul", class_="extra-details").find_all("li")[1].find_all("div")[1]
d_fecha = d_fecha.get_text(strip=True)
##
d_inscripción = soup.find("ul", class_="extra-details").find_all("li")[2].find_all("div")[1]
d_inscripción = d_inscripción.get_text(strip=True)
##
d_colección = soup.find("div", class_="col-md-12 block-type-terms bloque-coleccion").find("span")
d_colección = d_colección.get_text(strip=True)
##
d_genero = soup.find("div", class_="col-md-12 block-type-terms bloque-generos").find("span")
d_genero = d_genero.get_text(strip=True)
##
d_etiqueta = soup.find("ul", class_="outlined-list details-list social-nav item-count-4").find_all("span")[0]
d_etiqueta = d_etiqueta.get_text(strip=True)
##
d_credito = soup.find("div", class_="col-md-12 block-type-text block-field-credito-fotografa bloque-creditos").find("p")
d_credito = d_credito.get_text(strip=True)

print(d_titulo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 29
#      27 d_genero = d_genero.get_text(strip=True)
#      28 ##
# ---> 29 d_etiqueta = soup.find("ul", class_="outlined-list details-list social-nav item-count-4").find_all("span")[0]
#      30 d_etiqueta = d_etiqueta.get_text(strip=True)
#      31 ##
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
for i in range( len(l_ulr1) ): 
    
    req = requests.get(l_ulr1[i],
                       headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.0; WOW64; rv:24.0) Gecko/20100101 Firefox/24.0' }
                       )
    larespuesta = req.status_code 
    soup = BeautifulSoup(req.content.decode("utf-8"),  "html.parser")

    d_titulo = soup.find("h1", class_="case27-primary-text").text.strip() 
d_titulo = d_titulo.split("\n")[0]
##
d_creador = soup.find("span", class_="category-name").text.strip() 
d_creador = d_creador.split("\n")[0]
##
d_geoRef     = soup.find("div", class_="map-block-address").text.strip() 
d_geoRef  = d_geoRef.split("\n")[0]
##
d_tecnica = soup.find("ul", class_="extra-details").find_all("li")[0].find_all("div")[1]
d_tecnica = d_tecnica.get_text(strip=True)
##
d_fecha = soup.find("ul", class_="extra-details").find_all("li")[1].find_all("div")[1]
d_fecha = d_fecha.get_text(strip=True)
##
d_inscripción = soup.find("ul", class_="extra-details").find_all("li")[2].find_all("div")[1]
d_inscripción = d_inscripción.get_text(strip=True)
##
d_colección = soup.find("div", class_="col-md-12 block-type-terms bloque-coleccion").find("span")
d_colección = d_colección.get_text(strip=True)
##
d_genero = soup.find("div", class_="col-md-12 block-type-terms bloque-generos").find("span")
d_genero = d_genero.get_text(strip=True)
##
d_etiqueta = soup.find("ul", class_="outlined-list details-list social-nav item-count-4").find_all("span")[0]
d_etiqueta = d_etiqueta.get_text(strip=True)
##
d_credito = soup.find("div", class_="col-md-12 block-type-text block-field-credito-fotografa bloque-creditos").find("p")
d_credito = d_credito.get_text(strip=True)

print(d_credito)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 15
#      13 d_creador = d_creador.split("\n")[0]
#      14 ##
# ---> 15 d_geoRef     = soup.find("div", class_="map-block-address").text.strip()
#      16 d_geoRef  = d_geoRef.split("\n")[0]
#      17 ##
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
## crear lista vacias para llenar

l_titulo  = []
l_creador = [] 
l_geoRef  = [] 
l_tecnica   = []
l_fecha   = [] 
l_inscripción = [] 
l_colección = [] 
l_genero     = []
l_etiqueta    = []
l_credito    = []

# append elementos a listas segun largo de lista de url
for i in range( len(l_ulr1) ): # l_ulr1 
    l_titulo.append( d_titulo ) 
    l_creador.append( d_creador ) 
    l_geoRef.append( d_geoRef ) 
    l_tecnica.append( d_tecnica ) 
    l_fecha.append( d_fecha ) 
    l_inscripción.append( d_inscripción ) 
    l_colección.append( d_colección ) 
    l_genero.append( d_genero ) 
    l_etiqueta.append( d_etiqueta ) 
    l_credito.append( d_credito ) 


## Mostrar si los lee
print( l_titulo ) 
print( l_creador ) 
print( l_geoRef )
print( l_tecnica ) 
print( l_fecha ) 
print( l_inscripción ) 
print( l_colección ) 
print( l_genero ) 
print( l_etiqueta ) 
print( l_credito)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 24
#      22     l_colección.append( d_colección )
#      23     l_genero.append( d_genero )
# ---> 24     l_etiqueta.append( d_etiqueta )
#      25     l_credito.append( d_credito )
#      28 ## Mostrar si los lee
#
# NameError: name 'd_etiqueta' is not defined
